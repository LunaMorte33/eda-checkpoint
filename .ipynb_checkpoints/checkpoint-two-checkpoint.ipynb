# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:https://www.kaggle.com/datasets/andreuvallhernndez/myanimelist?resource=download&select=anime.csv
# https://www.kaggle.com/datasets/andreuvallhernndez/myanimelist?resource=download&select=manga.csv
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.mlab as mlab
import matplotlib

# %%
manga = pd.read_csv('manga.csv')
manga.head()
# Out:
#        id               title media_type  mean  num_scoring_users  \
# 0       2             Berserk      manga  9.45             262620
# 1      13           One Piece      manga  9.19             300393
# 2   23390  Shingeki no Kyojin      manga  8.57             359676
# 3  116778        Chainsaw Man      manga  8.72             256830
# 4    4632      Oyasumi Punpun      manga  9.03             138251
#
#                  status  num_volumes  num_chapters           start_date  \
# 0  currently_publishing          NaN           NaN  1989-08-25 00:00:00
# 1  currently_publishing          NaN           NaN  1997-07-22 00:00:00
# 2              finished         34.0         141.0  2009-09-09 00:00:00
# 3              finished         11.0          97.0  2018-12-03 00:00:00
# 4              finished         13.0         147.0  2007-03-15 00:00:00
#
#               end_date  ...  \
# 0                  NaN  ...
# 1                  NaN  ...
# 2  2021-04-09 00:00:00  ...
# ...

# %%
anime = pd.read_csv('anime.csv')
anime.head()
# Out:
#       id                             title media_type  mean  \
# 0   5114  Fullmetal Alchemist: Brotherhood         tv  9.14
# 1  11061            Hunter x Hunter (2011)         tv  9.05
# 2   9253                       Steins;Gate         tv  9.08
# 3     21                         One Piece         tv  8.65
# 4   1535                        Death Note         tv  8.62
#
#    num_scoring_users            status  num_episodes           start_date  \
# 0            1848530   finished_airing          64.0  2009-04-05 00:00:00
# 1            1491056   finished_airing         148.0  2011-10-02 00:00:00
# 2            1241454   finished_airing          24.0  2011-04-06 00:00:00
# 3            1079359  currently_airing           NaN  1999-10-20 00:00:00
# 4            2429917   finished_airing          37.0  2006-10-04 00:00:00
#
#               end_date        source  ...                      studios  \
# 0  2010-07-04 00:00:00         manga  ...                    ['Bones']
# ...

# %%
anime.columns
# Out:
# Index(['id', 'title', 'media_type', 'mean', 'num_scoring_users', 'status',
#        'num_episodes', 'start_date', 'end_date', 'source', 'num_list_users',
#        'popularity', 'num_favorites', 'rank', 'average_episode_duration',
#        'rating', 'start_season_year', 'start_season_season',
#        'broadcast_day_of_the_week', 'broadcast_start_time', 'genres',
#        'studios', 'synopsis', 'nsfw', 'created_at', 'updated_at',
#        'main_picture_medium', 'main_picture_large', 'alternative_titles_en',
#        'alternative_titles_ja', 'alternative_titles_synonyms'],
#       dtype='object')

# %%
manga.columns
# Out:
# Index(['id', 'title', 'media_type', 'mean', 'num_scoring_users', 'status',
#        'num_volumes', 'num_chapters', 'start_date', 'end_date',
#        'num_list_users', 'popularity', 'num_favorites', 'rank', 'genres',
#        'authors', 'synopsis', 'nsfw', 'created_at', 'updated_at',
#        'main_picture_medium', 'main_picture_large', 'alternative_titles_en',
#        'alternative_titles_ja', 'alternative_titles_synonyms'],
#       dtype='object')

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
manga.describe()
# Out:
#                  id          mean  num_scoring_users  num_episodes  \
# count  24024.000000  14169.000000       2.402400e+04  23220.000000
# mean   28466.676407      6.456660       1.749933e+04     16.399699
# std    17189.836675      0.899351       8.726322e+04     50.224352
# min        1.000000      1.850000       0.000000e+00      1.000000
# 25%     9995.250000      5.850000       2.300000e+01      1.000000
# 50%    33756.500000      6.470000       2.370000e+02      2.000000
# 75%    43930.250000      7.110000       3.055750e+03     13.000000
# max    52212.000000      9.150000       2.462613e+06   3057.000000
#
#        num_list_users    popularity  num_favorites          rank  \
# count    2.402400e+04  20559.000000   24024.000000  18657.000000
# mean     3.401683e+04  10280.000000     399.726440   9329.000000
# std      1.447044e+05   5935.016428    4059.616502   5385.956322
# min      0.000000e+00      1.000000       0.000000      1.000000
# ...

# %%
anime.describe()
# Out:
#                  id          mean  num_scoring_users  num_episodes  \
# count  24024.000000  14169.000000       2.402400e+04  23220.000000
# mean   28466.676407      6.456660       1.749933e+04     16.399699
# std    17189.836675      0.899351       8.726322e+04     50.224352
# min        1.000000      1.850000       0.000000e+00      1.000000
# 25%     9995.250000      5.850000       2.300000e+01      1.000000
# 50%    33756.500000      6.470000       2.370000e+02      2.000000
# 75%    43930.250000      7.110000       3.055750e+03     13.000000
# max    52212.000000      9.150000       2.462613e+06   3057.000000
#
#        num_list_users    popularity  num_favorites          rank  \
# count    2.402400e+04  20559.000000   24024.000000  18657.000000
# mean     3.401683e+04  10280.000000     399.726440   9329.000000
# std      1.447044e+05   5935.016428    4059.616502   5385.956322
# min      0.000000e+00      1.000000       0.000000      1.000000
# ...

# %%
#seeing how many null values are in each column. seems like a lot.
manga.isnull().sum()
# Out:
# id                                 0
# title                              0
# media_type                         0
# mean                           44941
# num_scoring_users                  0
# status                             0
# num_volumes                    16335
# num_chapters                   19849
# start_date                      4250
# end_date                       15190
# num_list_users                     0
# popularity                      7208
# num_favorites                      0
# rank                           25729
# genres                             0
# authors                            0
# synopsis                       21515
# nsfw                               0
# created_at                         0
# updated_at                         0
# main_picture_medium             2404
# main_picture_large              2404
# alternative_titles_en          48445
# alternative_titles_ja           2181
# alternative_titles_synonyms        0
# dtype: int64

# %%
anime.isnull().sum()
# Out:
# id                                 0
# title                              0
# media_type                         0
# mean                            9855
# num_scoring_users                  0
# status                             0
# num_episodes                     804
# start_date                      2847
# end_date                        4296
# source                          3768
# num_list_users                     0
# popularity                      3465
# num_favorites                      0
# rank                            5367
# average_episode_duration         918
# rating                          1009
# start_season_year               6451
# start_season_season             6451
# broadcast_day_of_the_week      20972
# broadcast_start_time           21108
# genres                             0
# studios                            0
# synopsis                        3261
# nsfw                               0
# created_at                         0
# ...

# %%
#find if any of the manga has been duplicated in the dataframe
dup_manga = manga.duplicated()
dup_manga.sum()
# Out:
# 0

# %%
#nothing has been duplicated. ~(@.@)~
dup_anime = anime.duplicated()
dup_anime.sum()
# Out:
# 0

# %%
manga[['genres']].head(10)
#manga[['genres']].describe()
#manga[['nsfw']].describe()
# Out:
#                                               genres
# 0  ['Action', 'Adventure', 'Award Winning', 'Dram...
# 1      ['Action', 'Adventure', 'Fantasy', 'Shounen']
# 2  ['Action', 'Award Winning', 'Drama', 'Gore', '...
# 3  ['Action', 'Adventure', 'Award Winning', 'Gore...
# 4  ['Drama', 'Psychological', 'Seinen', 'Slice of...
# 5  ['Action', 'Adventure', 'Fantasy', 'Martial Ar...
# 6  ['Action', 'Fantasy', 'Gore', 'Horror', 'Psych...
# 7  ['Action', 'Adventure', 'Historical', 'Horror'...
# 8                 ['Action', 'Adventure', 'Fantasy']
# 9  ['Action', 'Comedy', 'Parody', 'Seinen', 'Supe...

# %%
anime[['genres']].head(10)

#anime[['nsfw']].describe() (gonna have to clean both datasets and figure out why nsfw has different colors and what they mean, I might just delete it since it doesn't 
#have anything to do with what i'm trying to do with the datasets as the client wants a show that can be read/watched by all)
# Out:
#                                               genres
# 0  ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...
# 1      ['Action', 'Adventure', 'Fantasy', 'Shounen']
# 2  ['Drama', 'Psychological', 'Sci-Fi', 'Suspense...
# 3      ['Action', 'Adventure', 'Fantasy', 'Shounen']
# 4  ['Psychological', 'Shounen', 'Supernatural', '...
# 5  ['Action', 'Drama', 'Gore', 'Military', 'Shoun...
# 6  ['Action', 'Drama', 'Mecha', 'Military', 'Scho...
# 7  ['Action', 'Adventure', 'Fantasy', 'Martial Ar...
# 8  ['Action', 'Avant Garde', 'Drama', 'Mecha', 'P...
# 9      ['Drama', 'Romantic Subtext', 'Supernatural']

# %%
rating_counts = anime['rating'].value_counts()
rating_counts.head(20)
#want to see how many different ratings there are.
# Out:
# pg_13    7634
# g        6919
# pg       4665
# rx       1450
# r        1330
# r+       1017
# Name: rating, dtype: int64

# %%
anime[['title','rating','popularity']].head(25)
#i'm thinking the popularity comes from polls from watchers votes.
# Out:
#                                     title rating  popularity
# 0        Fullmetal Alchemist: Brotherhood      r         3.0
# 1                  Hunter x Hunter (2011)  pg_13        10.0
# 2                             Steins;Gate  pg_13        13.0
# 3                               One Piece  pg_13        26.0
# 4                              Death Note      r         2.0
# 5                      Shingeki no Kyojin      r         1.0
# 6         Code Geass: Hangyaku no Lelouch      r        17.0
# 7                      Naruto: Shippuuden  pg_13        16.0
# 8                 Neon Genesis Evangelion  pg_13        48.0
# 9                          Kimi no Na wa.  pg_13        11.0
# 10                       Kimetsu no Yaiba      r         9.0
# 11                Shigatsu wa Kimi no Uso  pg_13        21.0
# 12                         Koe no Katachi  pg_13        19.0
# 13             Tengen Toppa Gurren Lagann  pg_13        59.0
# ...

# %%
manga[['title','media_type','rank','popularity', 'genres']].head(20)
#rank raises questions like how are they being rank and whats the ranking system they use.
#manga is japanese, manhwa is korean.
# Out:
#                                                 title media_type    rank  \
# 0                                             Berserk      manga     1.0
# 1                                           One Piece      manga     3.0
# 2                                  Shingeki no Kyojin      manga    90.0
# 3                                        Chainsaw Man      manga    44.0
# 4                                      Oyasumi Punpun      manga     9.0
# 5                                              Naruto      manga   573.0
# 6                                         Tokyo Ghoul      manga   112.0
# 7     JoJo no Kimyou na Bouken Part 7: Steel Ball Run      manga     2.0
# 8                                       Solo Leveling     manhwa    45.0
# 9                                       One Punch-Man      manga    43.0
# 10                                             Bleach      manga  1255.0
# 11                                         Death Note      manga    50.0
# ...

# %%
anime[['num_scoring_users']].value_counts().sum()
# Out:
# 24024

# %%
anime[['media_type']].value_counts()
#ona An original net animation, known in Japan as web anime, is an anime that is directly released onto the Internet.
#ova is an episode created as an extra for promotional purposes or extras, they will not be aired on tv, they release on blue rays as extras or dvd.
# Out:
# media_type
# tv            8048
# movie         4088
# ova           4012
# ona           3144
# special       2544
# music         2116
# unknown         72
# dtype: int64

# %%
manga[['title', 'rank','popularity','genres','synopsis']].head(15)
#wondering if the rank is based on how many manga there are in the database in total.
# Out:
#                                               title    rank  popularity  \
# 0                                           Berserk     1.0         2.0
# 1                                         One Piece     3.0         3.0
# 2                                Shingeki no Kyojin    90.0         1.0
# 3                                      Chainsaw Man    44.0         5.0
# 4                                    Oyasumi Punpun     9.0        12.0
# 5                                            Naruto   573.0         8.0
# 6                                       Tokyo Ghoul   112.0         4.0
# 7   JoJo no Kimyou na Bouken Part 7: Steel Ball Run     2.0        27.0
# 8                                     Solo Leveling    45.0         9.0
# 9                                     One Punch-Man    43.0         6.0
# 10                                           Bleach  1255.0        13.0
# 11                                       Death Note    50.0        10.0
# ...

# %%
manga[['rank']].value_counts().sum()
#rank says 40,872 so I have to see if every title has a rank and if not why. how are the titles beig ranked.
#manga[['title']].value_counts().sum()
#theres 66,601 title
# Out:
# 40872

# %%
genre_counts = manga['genres'].value_counts()
manga.head(10)
# Out:
#        id                                            title media_type  mean  \
# 0       2                                          Berserk      manga  9.45
# 1      13                                        One Piece      manga  9.19
# 2   23390                               Shingeki no Kyojin      manga  8.57
# 3  116778                                     Chainsaw Man      manga  8.72
# 4    4632                                   Oyasumi Punpun      manga  9.03
# 5      11                                           Naruto      manga  8.07
# 6   33327                                      Tokyo Ghoul      manga  8.52
# 7    1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run      manga  9.27
# 8  121496                                    Solo Leveling     manhwa  8.72
# 9   44347                                    One Punch-Man      manga  8.73
#
#    num_scoring_users                status  num_volumes  num_chapters  \
# ...

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
plt.hist(manga['status'])
# Out:
# (array([ 9282.,     0., 56999.,     0.,     0.,   163.,     0.,    91.,
#             0.,    66.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
top20 = manga.head(20)
plt.scatter(x = top20['rank'], y = top20['genres'])

# %%
# manga_hist = ['media_type','mean','status','num_volumes','num_chapters','year','nsfw']

# for i in manga_hist:
#     bins = manga[i].nunique()
#     plt.figure(figsize=(25,5))
#     sns.histplot(manga, x=i,bins=bins)
#     plt.title(i)
#     plt.xticks(rotation=90)
#     plt.show()

# %%
plt.hist(anime['status'])
plt.show()

# %%
sns.histplot(anime['genres'], color='red')
plt.show()

# %%
# hist = ['media_type','mean','status','num_episodes',
#         'source','rating',
#         'start_season_year','broadcast_day_of_the_week','broadcast_start_time']

# for i in hist:
#     bins = anime[i].nunique()
#     plt.figure(figsize=(25,5))
#     sns.histplot(anime, x=i,bins=bins)
#     plt.title(i)
#     plt.xticks(rotation=90)
#     plt.show()

# %%
plt.figure(figsize=(16, 8))

sns.histplot(anime, x='genres')
# i'm having issues with my visualizations not loading.

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# needs some cleaning, also a bit confusing since it doesnt explain what its being ranked out of or why nsfw is described with colors instead of rating.
# 2. Do you have any concerns about your dataset?
# wondering if the dataset is big enough, it is current so that will help but I need to understand the tables better.
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# lots of null values but some are usefull since its being used as a standby for specific tables like num_volumes for currently_publishing, since the series is not finished it will be blank('null').
